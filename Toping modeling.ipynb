# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import STOPWORDS,WordCloud
import gensim
from gensim.models import CoherenceModel
from gensim import corpora
import pandas as pd
from pprint import pprint
import string
import os
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\HIKMAB~1\AppData\Local\Temp/ipykernel_8756/2892191122.py in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from wordcloud import STOPWORDS,WordCloud
#       6 import gensim
#       7 from gensim.models import CoherenceModel
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# data loader class
class DataLoader:
    def __init__(self, dir_name, file_name):
        self.dir_name= dir_name
        self.file_name = file_name
        

#read data
    def read_csv(self):
        os.chdir(self.dir_name)
        tweets_df= pd.read_csv(self.file_name)
        return tweets_df
#object creation

DataLoader_obj = DataLoader('C:/Users/hikma/Desktop/10 accadamay/week0/Twitter-Data-Analysis','processed_tweet_data.csv')
tweets_df= DataLoader.read_csv(DataLoader_obj)

tweets_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HIKMAB~1\AppData\Local\Temp/ipykernel_10464/445230764.py in <module>
#      14
#      15 DataLoader_obj = DataLoader('C:/Users/hikma/Desktop/10 accadamay/week0/Twitter-Data-Analysis','processed_tweet_data.csv')
# ---> 16 tweets_df= DataLoader.read_csv(DataLoader_obj)
#      17
#      18 tweets_df.head()
#
# C:\Users\HIKMAB~1\AppData\Local\Temp/ipykernel_10464/445230764.py in read_csv(self)
#       8 #read data
#       9     def read_csv(self):
# ---> 10         os.chdir(self.dir_name)
#      11         tweets_df= pd.read_csv(self.file_name)
#      12         return tweets_df
#
# NameError: name 'os' is not defined

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = text.replace('rt', "", 1)
    return text

ctext = lambda item: clean_text(item)
def preprocess_data(self):
    
   
    tweets_df['original_text']=tweets_df['original_text'].astype(str)
    tweets_df['clean_text']= tweets_df['original_text'].apply(ctext)
    tweets_df['clean_text']= tweets_df['clean_text'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))
    
    #Converting tweets to list of words For feature engineering
    sentence_list = [tweet for tweet in tweets_df['clean_text']]
    word_list = [sent.split() for sent in sentence_list]
     #Create dictionary which contains Id and word 
    word_to_id = corpora.Dictionary(word_list)
    corpus_1= [word_to_id.doc2bow(tweet) for tweet in word_list]
    return word_list, word_to_id, corpus_1
preprocess_data(tweets_df)
# compute Preplexity

#It's a measure of how good the model is. The lower the better. Perplexity is a negative value
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  
doc_lda = lda_model[corpus]

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=word_list, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\n Ldamodel Coherence Score/Accuracy on Tweets: ', coherence_lda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HIKMAB~1\AppData\Local\Temp/ipykernel_10464/1321227373.py in <module>
#      22     corpus_1= [word_to_id.doc2bow(tweet) for tweet in word_list]
#      23     return word_list, word_to_id, corpus_1
# ---> 24 preprocess_data(tweets_df)
#      25 # compute Preplexity
#      26
#
# NameError: name 'tweets_df' is not defined

# %%
# !pip install pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import pickle
import pyLDAvis
#visualize the topics
pyLDAvis.enable_notebook()
LDAvis_prepared = gensimvis.prepare(lda_model, corpus, id2word)
LDAvis_prepared
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Downloading pyLDAvis-3.3.0.tar.gz (1.7 MB)
#   ERROR: Command errored out with exit status 2:
#    command: 'C:\Users\Hikma Brhan\anaconda3\python.exe' 'C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Hikma Brhan\AppData\Local\Temp\pip-build-env-sz7ny2zo\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools
#        cwd: None
#   Complete output (80 lines):
#   Collecting setuptools
#     Downloading setuptools-62.1.0-py3-none-any.whl (1.1 MB)
#   ERROR: Exception:
#   Traceback (most recent call last):
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#       yield
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\urllib3\response.py", line 519, in read
#       data = self._fp.read(amt) if not fp_closed else b""
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#       data = self.__fp.read(amt)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\http\client.py", line 462, in read
#       n = self.readinto(b)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\http\client.py", line 506, in readinto
#       n = self.fp.readinto(b)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\socket.py", line 704, in readinto
#       return self._sock.recv_into(b)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\ssl.py", line 1241, in recv_into
#       return self.read(nbytes, buffer)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\ssl.py", line 1099, in read
#       return self._sslobj.read(len, buffer)
#   socket.timeout: The read operation timed out
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\cli\base_command.py", line 173, in _main
#       status = self.run(options, args)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\cli\req_command.py", line 203, in wrapper
#       return func(self, options, args)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\commands\install.py", line 315, in run
#       requirement_set = resolver.resolve(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#       result = self._result = resolver.resolve(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 472, in resolve
#       state = resolution.resolve(requirements, max_rounds=max_rounds)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#       self._add_to_criteria(self.state.criteria, r, parent=None)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#       if not criterion.candidates:
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#       return bool(self._sequence)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 140, in __bool__
#       return any(self)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 128, in <genexpr>
#       return (c for c in iterator if id(c) not in self._incompatible_ids)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 32, in _iter_built
#       candidate = func()
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\factory.py", line 204, in _make_candidate_from_link
#       self._link_candidate_cache[link] = LinkCandidate(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 295, in __init__
#       super().__init__(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#       self.dist = self._prepare()
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#       dist = self._prepare_distribution()
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 305, in _prepare_distribution
#       return self._factory.preparer.prepare_linked_requirement(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#       return self._prepare_linked_requirement(req, parallel_builds)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\operations\prepare.py", line 550, in _prepare_linked_requirement
#       local_file = unpack_url(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\operations\prepare.py", line 239, in unpack_url
#       file = get_http_url(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\operations\prepare.py", line 102, in get_http_url
#       from_path, content_type = download(link, temp_dir.path)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\network\download.py", line 145, in __call__
#       for chunk in chunks:
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\cli\progress_bars.py", line 144, in iter
#       for x in it:
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_internal\network\utils.py", line 63, in response_chunks
#       for chunk in response.raw.stream(
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\urllib3\response.py", line 576, in stream
#       data = self.read(amt=amt, decode_content=decode_content)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\urllib3\response.py", line 541, in read
#       raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     File "C:\Users\Hikma Brhan\anaconda3\lib\contextlib.py", line 137, in __exit__
#       self.gen.throw(typ, value, traceback)
#     File "C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#       raise ReadTimeoutError(self._pool, None, "Read timed out.")
#   pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/03/a5/15a0da6b0150b8b68610cc78af80364a80a9a4c8b6dd5ee549b8989d4b60/pyLDAvis-3.3.1.tar.gz#sha256=f181b88401f6f8f17d5a99ab69ef99b2c496faa276919262f8ec246307b7050c (from https://pypi.org/simple/pyldavis/). Command errored out with exit status 2: 'C:\Users\Hikma Brhan\anaconda3\python.exe' 'C:\Users\Hikma Brhan\AppData\Local\Temp\pip-standalone-pip-ah9ju1e6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Hikma Brhan\AppData\Local\Temp\pip-build-env-sz7ny2zo\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools Check the logs for full command output.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\http\client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 472, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 140, in __bool__
#     return any(self)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 128, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 32, in _iter_built
#     candidate = func()
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 295, in __init__
#     super().__init__(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 145, in __call__
#     for chunk in chunks:
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 144, in iter
#     for x in it:
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\Hikma Brhan\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\HIKMAB~1\AppData\Local\Temp/ipykernel_10464/280377910.py in <module>
#       1 get_ipython().system('pip install pyLDAvis')
# ----> 2 import pyLDAvis.gensim_models as gensimvis
#       3 import pickle
#       4 import pyLDAvis
#       5 #visualize the topics
#
# ModuleNotFoundError: No module named 'pyLDAvis'
